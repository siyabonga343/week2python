# %%
#formulate an empty list where I will store m numbers.
my_list = []

# Step 2: Append the elements 10, 20, 30, 40
my_list.append(10)
my_list.append(20)
my_list.append(30)
my_list.append(40)

# Inserting 15 at the second position where it is reffered to index 1 according to python.
my_list.insert(1, 15)

# Extend "my_list" with another list [50, 60, 70]
my_list.extend([50, 60, 70])

# Removing the last element from "my_list" 
my_list.pop()

# Sorting "my_list" from smallest to biggest number(ascending order) and We now find and print the index of the value 30 from "my_list"
my_list.sort()
index_of_30 = my_list.index(30)
print("Index of 30:", index_of_30)
# !git init
# !git remote add origin https://github.com/https://github.com/siyabonga343/week2python.git
# !git add .
# !git commit -m "Add assignment submission"
# !git branch -M main
# !git push -u origin main
# Out:
# Index of 30: 3
# Reinitialized existing Git repository in C:/Users/Perfect Elect/.git/
# error: remote origin already exists.
# ...
# ...
# ...
# error: open("AppData/Local/Comms/UnistoreDB/USS.jtx"): Permission denied
# error: unable to index file 'AppData/Local/Comms/UnistoreDB/USS.jtx'
# fatal: adding files failed
# ...
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/https://github.com/siyabonga343/week2python.git'
